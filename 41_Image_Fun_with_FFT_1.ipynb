# %% [markdown]
# <a href="https://colab.research.google.com/github/JoDeMiro/ImageProcessing/blob/main/41_Image_Fun_with_FFT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tartalom
#
# A programot tőle függetlenül megírtam már korábban, de a magyarázata annyira jó, hogy ide raktam.
#
# https://youtu.be/uB3v6n8t2dQ?t=737
#
# Az egyik legjobb, legszemléletesebb magyarázat, hasonlata a Fourier Transzformációra.

# %%
import numpy as np
import matplotlib.pyplot as plt

import skimage.io

from mpl_toolkits.mplot3d import axes3d

# %%
A = skimage.io.imread('https://github.com/JoDeMiro/ImageProcessing/blob/main/images/woman2.jpg?raw=true')

B = np.mean(A, -1)

plt.figure()
plt.imshow(B, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
X, Y = np.meshgrid(np.arange(1, B.shape[1] + 1), np.arange(1, B.shape[0] + 1))

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

div = 10
ax.plot_surface(X[0::div, 0::div], Y[0::div, 0::div], B[0::div, 0::div], cmap='viridis', edgecolor='gray')
ax.mouse_init()
ax.view_init(270, 270)
plt.show()

# %%
X, Y = np.meshgrid(np.arange(1, B.shape[1] + 1), np.arange(1, B.shape[0] + 1))

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

div = 10
x = X[0::div, 0::div]
y = Y[0::div, 0::div]
z = B[0::div, 0::div]
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);
ax.mouse_init()
ax.view_init(250, 270)
plt.show()

# %%
# %%capture
# !pip install plotly
# !pip install chart-studio

# %%
import chart_studio.plotly as py
import plotly.graph_objects as go
from plotly.offline import iplot

# %%
surface = go.Surface(x = x, y = y, z = z)
data = [surface]

fig = go.Figure(data = data)

fig.update_layout(title = '', autosize=False,
                  width = 800, height = 600,
                  scene = dict(
                    xaxis_title = 'x',
                    yaxis_title = 'y',
                    zaxis_title = ' '),
                  margin = dict(l = 65, r = 50, b = 65, t = 60))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b3f4ff29-bde6-49c1-a44f-7619d0f2e613" class="plotly-graph-div" style="height:600px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3f4ff29-bde6-49c1-a44f-7619d0f2e613")) {
#                     Plotly.newPlot(
#                         'b3f4ff29-bde6-49c1-a44f-7619d0f2e613',
# ...

# %%
surface = go.Surface(x = x, y = y, z = z)
data = [surface]

fig = go.Figure(data = data)

fig.update_layout(title = '', autosize=False,
                  width = 800, height = 600,
                  scene = dict(
                    xaxis_title = 'x',
                    yaxis_title = 'y',
                    zaxis_title = ' '),
                  margin = dict(l = 1, r = 1, b = 1, t = 1))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="182dbc8a-0a00-4808-8bb1-f00706e898cb" class="plotly-graph-div" style="height:600px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("182dbc8a-0a00-4808-8bb1-f00706e898cb")) {
#                     Plotly.newPlot(
#                         '182dbc8a-0a00-4808-8bb1-f00706e898cb',
# ...
